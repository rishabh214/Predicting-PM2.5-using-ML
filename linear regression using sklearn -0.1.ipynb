# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('data_normalized.csv')
df
# Out:
#         pm10  temp      bp      rh      ws     co      o3     nox     so2  \
# 0     0.7487  1.00  0.8966  0.8795  0.0556  0.780  0.1431  0.7096  0.0085
# 1     0.7487  0.90  0.8966  0.8313  0.1296  0.147  0.1431  0.2494  0.0790
# 2     0.7487  0.90  0.8966  0.8313  0.0741  0.105  0.1431  0.2358  0.0790
# 3     0.7487  0.70  0.8966  0.8313  0.0556  0.048  0.1431  0.1800  0.0790
# 4     0.4682  1.00  0.8966  0.8675  0.0185  0.232  0.1431  0.1812  0.0790
# ...      ...   ...     ...     ...     ...    ...     ...     ...     ...
# 7923  0.0250  0.20  0.9655  0.3976  0.4815  0.052  0.1779  0.0142  0.0415
# 7924  0.0292  0.20  0.9655  0.4096  0.3704  0.052  0.1782  0.0146  0.0390
# 7925  0.0292  0.20  0.9655  0.4458  0.2407  0.056  0.1698  0.0162  0.0375
# 7926  0.0292  0.20  0.9655  0.4578  0.2593  0.068  0.1557  0.0182  0.0355
# 7927  0.0000  0.28  0.9655  0.4819  0.2037  0.076  0.1431  0.0198  0.0355
#
#       pm2.5
# 0       961
# 1       565
# 2       565
# 3       565
# 4       334
# ...     ...
# 7923      5
# 7924      6
# 7925      6
# 7926      6
# 7927      6
#
# [7928 rows x 10 columns]

# %%
df.dtypes
df.isnull().sum()
# Out:
# pm10     0
# temp     0
# bp       0
# rh       0
# ws       0
# co       0
# o3       0
# nox      0
# so2      0
# pm2.5    0
# dtype: int64

# %%
df.describe()
# Out:
#               pm10         temp           bp           rh           ws  \
# count  7928.000000  7928.000000  7928.000000  7928.000000  7928.000000
# mean      0.222536     0.559962     0.914146     0.593921     0.254432
# std       0.137649     0.182614     0.164633     0.209918     0.182978
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.134500     0.400000     0.931000     0.433700     0.111100
# 50%       0.194000     0.600000     0.931000     0.614500     0.240700
# 75%       0.280500     0.700000     0.965500     0.771100     0.388900
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 co           o3          nox          so2        pm2.5
# count  7928.000000  7928.000000  7928.000000  7928.000000  7928.000000
# mean      0.134310     0.165534     0.107975     0.078993   122.365414
# std       0.136696     0.155986     0.125329     0.077006    90.349835
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.066000     0.050600     0.040200     0.038000    60.000000
# 50%       0.092000     0.117200     0.066200     0.064600   102.000000
# 75%       0.142000     0.230750     0.119650     0.083600   159.000000
# max       1.000000     1.000000     1.000000     1.000000   974.000000

# %%
df
# Out:
#         pm10  temp      bp      rh      ws     co      o3     nox     so2  \
# 0     0.7487  1.00  0.8966  0.8795  0.0556  0.780  0.1431  0.7096  0.0085
# 1     0.7487  0.90  0.8966  0.8313  0.1296  0.147  0.1431  0.2494  0.0790
# 2     0.7487  0.90  0.8966  0.8313  0.0741  0.105  0.1431  0.2358  0.0790
# 3     0.7487  0.70  0.8966  0.8313  0.0556  0.048  0.1431  0.1800  0.0790
# 4     0.4682  1.00  0.8966  0.8675  0.0185  0.232  0.1431  0.1812  0.0790
# ...      ...   ...     ...     ...     ...    ...     ...     ...     ...
# 7923  0.0250  0.20  0.9655  0.3976  0.4815  0.052  0.1779  0.0142  0.0415
# 7924  0.0292  0.20  0.9655  0.4096  0.3704  0.052  0.1782  0.0146  0.0390
# 7925  0.0292  0.20  0.9655  0.4458  0.2407  0.056  0.1698  0.0162  0.0375
# 7926  0.0292  0.20  0.9655  0.4578  0.2593  0.068  0.1557  0.0182  0.0355
# 7927  0.0000  0.28  0.9655  0.4819  0.2037  0.076  0.1431  0.0198  0.0355
#
#       pm2.5
# 0       961
# 1       565
# 2       565
# 3       565
# 4       334
# ...     ...
# 7923      5
# 7924      6
# 7925      6
# 7926      6
# 7927      6
#
# [7928 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['pm10', 'temp', 'bp', 'rh', 'ws', 'co', 'o3', 'nox', 'so2', 'pm2.5'], dtype='object')

# %%
Y=df['pm2.5']

# %%
X=df[['pm10', 'temp', 'bp', 'rh', 'ws', 'co', 'o3', 'nox', 'so2']]
#X=df[['pm10','rh']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split( X,Y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.coef_
# Out:
# array([554.27040991,   5.39540667,  -8.83052428,  73.39676647,
#         -6.60124899,  60.46284587,  -1.41254089, -80.44311669,
#        -35.3924772 ])

# %%
predictions=lm.predict(X_test)

# %%
plt.figure(figsize=(20,10))
plt.scatter(Y_test,predictions)
sns.regplot(Y_test,predictions,scatter=False,color='purple')
plt.xlabel('Y_test(trueValues)')
plt.ylabel('predicted values')
plt.show()

# %%
from sklearn import metrics

# %%
print('MAE',metrics.mean_absolute_error(Y_test,predictions))
print('MSE',metrics.mean_squared_error(Y_test,predictions))
print('RMSE',np.sqrt(metrics.mean_squared_error(Y_test,predictions)))
# Out:
# MAE 23.05737329361009
# MSE 1494.7819727246556
# RMSE 38.662410332578276

# %%
np.mean(Y_test-predictions)**2
# Out:
# 0.5812975186048315
